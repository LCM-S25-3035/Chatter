# %%
pip install transformers accelerate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install sentencepiece

# %%
import sentencepiece
print("SentencePiece is available ✅")
# Out:
# SentencePiece is available ✅

# %%
import gradio as gr
import csv
import os

# Your cleaned generated questions list
questions = [
    "What is that no one ever expected. rocky completely dominates the first round, leaving lang enraged and bewildered after the bell. lang gains the upper hand in the second round, and rocky adopts an entirely different strategy that angers and confuses apollo by intentionally taking a beating from lang, even getting knocked down twice, all the while taunting lang that he cannot knock him out. by the third round, lang, who?",
    "What is the forbidden zone use their psychic powers to deter the apes, ursus and his gorillas are frightened, but dr zaius becomes enraged, charging forward. ursus and his soldiers then follow zaius, finding the entrance to the mutant city and leading the apes into the heart of the mutant world which houses a nuclear weapon. ursus meets the mutant leader, who?",
    "Tell me something about people of spanish descent english radio actresses...",
    "What is with gloria. however, melman the giraffe shows up and divulges romantic feelings for gloria. this causes gloria to break up with moto moto. okapi girl an unnamed female okapi voiced by taraji p. henson appears in madly madagascar, whom marty finds himself in love with. she?",
    "What is 4 out of 4 stars and screened it as part of his ebertfest festival. 4 ebert wrote, there has never been a movie quite like northfork, but if you wanted to put it on a list, you would also include days of heaven and wings of desire. it has the desolate open spaces of the first, the angels of the second, and the feeling in both of deep sadness and pity. the movie?",
    "Tell me something about recordings produced by brian rawling song recordin...",
    "What is for a spaceship simulator. she helps the gang fight anti pops and streaming in the finale. recap robot recap robot voiced by matthew mercer?",
    "What is back to the present. he then reveals himself to be an old man in disguise who just wanted to be a brilliant prank caller and asks to go with them. he?",
    "What is point and click a mouse typically controls the motion of a pointer in two dimensions in a graphical user interface gui. the mouse turns movements of the hand backward and forward, left and right into equivalent electronic signals that in turn are used to move the pointer. the relative movements of the mouse on the surface are applied to the position of the pointer on the screen, which signals the point where actions of the user take place, so hand movements are replicated by the pointer. 0 clicking or pointing stopping movement while the cursor?",
    "What is for other uses, see sycorax disambiguation. sycorax stkereeks?",
    "What is senator teresa hurst to be his running mate, as winning pennsylvania would increase his chances of ensuring neither major party s candidate would achieve a majority in the electoral college. on election night, dalton wins several key states, including pennsylvania, guaranteeing that neither major party candidate secures a majority. thanks to the efforts of russell jackson, dalton?",
    "Tell me something about of annihilation, have returned to the people at la...",
    "What is never going to come back ever again. parker parker voiced by ty burrell?",
    "What is in a studio in wardour street and put a cow in it, to signify projected on a screen behind her, which are later replaced by a shot of a reality. crowd walking down a street. stewart?"
]

# CSV file for storing feedback
feedback_csv = "user_feedback.csv"

# Create file and header if not exists
if not os.path.exists(feedback_csv):
    with open(feedback_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["question", "user_feedback"])

def submit_feedback(question, feedback):
    # Append feedback to CSV file
    with open(feedback_csv, 'a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow([question, feedback])
    return "✅ Feedback saved. Thanks!"

with gr.Blocks() as demo:
    gr.Markdown("# 🤖 WikiBot User Feedback Collector")
    question_dropdown = gr.Dropdown(choices=questions, label="Select a question to answer")
    feedback_textbox = gr.Textbox(label="Your feedback about the answer", lines=4, placeholder="Type your feedback here...")
    submit_btn = gr.Button("Submit Feedback")
    status = gr.Textbox(label="Status", interactive=False)

    submit_btn.click(submit_feedback, inputs=[question_dropdown, feedback_textbox], outputs=status)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import csv
import os

# Load your dataset CSV (adjust path)
wiki_path = r"C:\Users\choud\Downloads\wiki_hybrid_chunks_300.csv"
df = pd.read_csv(wiki_path)

# Example: Your cleaned/generated questions list (replace with your actual generated list)
questions = [
    "What is that no one ever expected. rocky completely dominates the first round, leaving lang enraged and bewildered after the bell. lang gains the upper hand in the second round, and rocky adopts an entirely different strategy that angers and confuses apollo by intentionally taking a beating from lang, even getting knocked down twice, all the while taunting lang that he cannot knock him out. by the third round, lang, who?",
    "What is the forbidden zone use their psychic powers to deter the apes, ursus and his gorillas are frightened, but dr zaius becomes enraged, charging forward. ursus and his soldiers then follow zaius, finding the entrance to the mutant city and leading the apes into the heart of the mutant world which houses a nuclear weapon. ursus meets the mutant leader, who?",
    # ... add all your generated questions here ...
]

# Map each question to its chunk_text answer by matching approx.
# (Here, for demo, we just map the question to a random chunk_text for example)
# In your real code, build this mapping carefully during question generation.

import random
question_to_chunk = {}
for q in questions:
    # Just pick a random chunk as answer for demo (replace with your actual mapping)
    sample_chunk = df.sample(1).iloc[0]['chunk_text']
    question_to_chunk[q] = sample_chunk

# Feedback CSV
feedback_csv = "user_feedback.csv"
if not os.path.exists(feedback_csv):
    with open(feedback_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["question", "user_feedback"])

def show_answer(question):
    return question_to_chunk.get(question, "No answer found.")

def submit_feedback(question, feedback):
    with open(feedback_csv, 'a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow([question, feedback])
    return "✅ Feedback saved. Thank you!"

with gr.Blocks() as demo:
    gr.Markdown("# 🤖 WikiBot User Feedback Collector")

    question_dropdown = gr.Dropdown(choices=questions, label="Select a question")
    answer_display = gr.Textbox(label="Answer", interactive=False, lines=6)
    feedback_textbox = gr.Textbox(label="Your feedback about this answer", lines=4, placeholder="Type your feedback here...")
    submit_btn = gr.Button("Submit Feedback")
    status = gr.Textbox(label="Status", interactive=False)

    question_dropdown.change(fn=show_answer, inputs=question_dropdown, outputs=answer_display)
    submit_btn.click(fn=submit_feedback, inputs=[question_dropdown, feedback_textbox], outputs=status)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import csv
import os
import re

# Load your dataset CSV (adjust path)
wiki_path = r"C:\Users\choud\Downloads\wiki_hybrid_chunks_300.csv"
df = pd.read_csv(wiki_path)

def clean_text(text):
    text = re.sub(r'\b(retrieved|retrieval)\b.*?(\d{4}|\d{1,2}, \d{4})', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\b\d{1,2} [A-Za-z]+ \d{4}\b', '', text)
    text = re.sub(r'\b[A-Za-z]+ \d{1,2}, \d{4}\b', '', text)
    text = re.sub(r'\[[^\]]*\]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def is_chunk_useful(text):
    if len(text) < 30:
        return False
    if len(re.findall(r'\d', text)) > 10:
        return False
    return True

def first_n_words(s, n=5):
    return ' '.join(s.strip().split()[:n])

def generate_question(text):
    text = clean_text(text)
    if not is_chunk_useful(text):
        return None
    
    if " is " in text:
        subject = first_n_words(text.split(" is ")[0])
        return f"What is {subject}?"
    elif " was " in text:
        subject = first_n_words(text.split(" was ")[0])
        return f"Who was {subject}?"
    elif " are " in text:
        subject = first_n_words(text.split(" are ")[0])
        return f"What are {subject}?"
    elif " refers to " in text:
        subject = first_n_words(text.split(" refers to ")[0])
        return f"What does {subject} refer to?"
    else:
        subject = first_n_words(text)
        return f"What is {subject}?"

# Generate questions and map them to answers
n = min(150, len(df))
sampled_rows = df.sample(n=n, replace=False, random_state=42)

question_to_chunk = {}
for _, row in sampled_rows.iterrows():
    question = generate_question(row['chunk_text'])
    if question:
        question_to_chunk[question] = clean_text(row['chunk_text'])

questions = list(question_to_chunk.keys())

# Feedback CSV setup
feedback_csv = "user_feedback.csv"
if not os.path.exists(feedback_csv):
    with open(feedback_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["question", "user_feedback"])

def show_answer(question):
    return question_to_chunk.get(question, "No answer found.")

def submit_feedback(question, feedback):
    if question and feedback.strip():
        with open(feedback_csv, 'a', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow([question, feedback])
        return "✅ Feedback saved. Thank you!"
    return "⚠️ Please select a question and enter feedback."

with gr.Blocks() as demo:
    gr.Markdown("# 🤖 WikiBot User Feedback Collector")

    question_dropdown = gr.Dropdown(choices=questions, label="Select a question")
    answer_display = gr.Textbox(label="Answer", interactive=False, lines=6)
    feedback_textbox = gr.Textbox(label="Your feedback about this answer", lines=4, placeholder="Type your feedback here...")
    submit_btn = gr.Button("Submit Feedback")
    status = gr.Textbox(label="Status", interactive=False)

    question_dropdown.change(fn=show_answer, inputs=question_dropdown, outputs=answer_display)
    submit_btn.click(fn=submit_feedback, inputs=[question_dropdown, feedback_textbox], outputs=status)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr
import pandas as pd
import csv
import os
import re

# Load your dataset CSV (adjust path)
wiki_path = r"C:\Users\choud\Downloads\wiki_hybrid_chunks_300.csv"
df = pd.read_csv(wiki_path)

def clean_text(text):
    text = re.sub(r'\b(retrieved|retrieval)\b.*?(\d{4}|\d{1,2}, \d{4})', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\b\d{1,2} [A-Za-z]+ \d{4}\b', '', text)
    text = re.sub(r'\b[A-Za-z]+ \d{1,2}, \d{4}\b', '', text)
    text = re.sub(r'\[[^\]]*\]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def is_chunk_useful(text):
    if len(text) < 30:
        return False
    if len(re.findall(r'\d', text)) > 10:
        return False
    return True

def first_n_words(s, n=5):
    return ' '.join(s.strip().split()[:n])

def generate_question(text):
    text = clean_text(text)
    if not is_chunk_useful(text):
        return None
    
    if " is " in text:
        subject = first_n_words(text.split(" is ")[0])
        return f"What is {subject}?"
    elif " was " in text:
        subject = first_n_words(text.split(" was ")[0])
        return f"Who was {subject}?"
    elif " are " in text:
        subject = first_n_words(text.split(" are ")[0])
        return f"What are {subject}?"
    elif " refers to " in text:
        subject = first_n_words(text.split(" refers to ")[0])
        return f"What does {subject} refer to?"
    else:
        subject = first_n_words(text)
        return f"What is {subject}?"

# Generate questions and map them to answers
n = min(150, len(df))
sampled_rows = df.sample(n=n, replace=False, random_state=42)

question_to_chunk = {}
for _, row in sampled_rows.iterrows():
    question = generate_question(row['chunk_text'])
    if question:
        question_to_chunk[question] = clean_text(row['chunk_text'])

questions = list(question_to_chunk.keys())

# Feedback CSV setup
feedback_csv = "user_feedback.csv"
if not os.path.exists(feedback_csv):
    with open(feedback_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(["question", "user_feedback"])

def show_answer(question):
    full_text = question_to_chunk.get(question, "No answer found.")
    sentences = full_text.split('. ')
    summary = '. '.join(sentences[:2])  # First two sentences
    if not summary.endswith('.'):
        summary += '.'
    return summary

def submit_feedback(question, feedback):
    if question and feedback.strip():
        with open(feedback_csv, 'a', newline='', encoding='utf-8') as f:
            writer = csv.writer(f)
            writer.writerow([question, feedback])
        return "✅ Feedback saved. Thank you!"
    return "⚠️ Please select a question and enter feedback."

with gr.Blocks() as demo:
    gr.Markdown("# 🤖 WikiBot User Feedback Collector")

    question_dropdown = gr.Dropdown(choices=questions, label="Select a question")
    answer_display = gr.Textbox(label="Answer", interactive=False, lines=6)
    feedback_textbox = gr.Textbox(label="Your feedback about this answer", lines=4, placeholder="Type your feedback here...")
    submit_btn = gr.Button("Submit Feedback")
    status = gr.Textbox(label="Status", interactive=False)

    question_dropdown.change(fn=show_answer, inputs=question_dropdown, outputs=answer_display)
    submit_btn.click(fn=submit_feedback, inputs=[question_dropdown, feedback_textbox], outputs=status)

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * Running on public URL: https://fe8ebcc4b01b842c65.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fe8ebcc4b01b842c65.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
